# %%
import pandas as pd
import numpy as np
import math

# %%
df =pd.read_excel('C:\\Users\\Carlos\\Documents\\GitHub\\py-Aguirre-Maldonado-Carlos-Arturo\\Examen IIB\\examen-python\\documentos iniciales\\articulos.xlsx')

# %%
df.rename(columns={'LISTADO DE PRODUCTOS CON SU RESPECTIVO NOMBRE Y PRESENTACIÓN.': 'especificación',
                   'Unnamed: 1': 'nombre',
                   'Unnamed: 2': 'factor',
                   'Unnamed: 3': 'presentación'}, inplace=True)

# %%
especificacion = []
nombre = []
factor = []
presentacion = []
sub = []

# %%
str(df['nombre'][0])
# Out:
# 'nan'

# %%
i=0
aux=''
for row in df['nombre']:
    if(str(df['presentación'][i])=='nan'):
        aux = df['especificación'][i]
    
    if((str(df['presentación'][i])!='PRESENTACIÓN')and(str(df['presentación'][i])!='nan')):
        especificacion.append(df['especificación'][i])
        nombre.append(df['nombre'][i])
        factor.append(df['factor'][i])
        presentacion.append(df['presentación'][i])
        sub.append(aux)
        
    i=i+1

# %%
dfdic={
    'especificacion' : especificacion,
    'nombre' : nombre,
    'factor' : factor,
    'presentacion' : presentacion,
    'sub' :sub
}

# %%
df3 = pd.DataFrame(dfdic)
df3
# Out:
#                             especificacion  \
# 0                    SINTETICO SAE 5W40 SN
# 1                    SINTETICO SAE 5W40 SN
# 2                    SINTETICO SAE 0W16 SN
# 3                    SINTETICO SAE 0W16 SN
# 4                    SINTETICO SAE 0W16 SN
# 5            SINTETICO SAE 0W20 SN, SM, SL
# 6            SINTETICO SAE 0W20 SN, SM, SL
# 7                SAE 10W30 SL JASO MA/MA2
# 8                SAE 10W40 SL JASO MA/MA2
# 9                SAE 10W40 SL JASO MA/MA2
# 10               SAE 20W50 SL JASO MA/MA2
# 11               SAE 20W50 SL JASO MA/MA2
# 12                               SAE 40 SL
# 13                               SAE 40 SL
# 14                               SAE 40 SL
# 15                               SAE 40 SG
# 16                               SAE 40 SG
# 17                               SAE 40 SG
# 18                       SAE 10W30 CJ-4/SN
# 19                       SAE 10W30 CJ-4/SN
# 20                       SAE 10W30 CJ-4/SN
# 21                       SAE 10W30 CJ-4/SN
# 22                       SAE 10W30 CJ-4/SN
# 23                       SAE 15W40 CK-4/SN
# 24                       SAE 15W40 CK-4/SN
# 25                       SAE 15W40 CK-4/SN
# 26                       SAE 15W40 CK-4/SN
# 27                       SAE 15W40 CK-4/SN
# 28                       SAE 15W40 CJ-4/SN
# 29                               SAE 15W40
# ..                                     ...
# 119                ISO AT 68 (COMPRESORES)
# 120                  ISO 100 (COMPRESORES)
# 121                  ISO 100 (COMPRESORES)
# 122                  ISO 150 (COMPRESORES)
# 123                  ISO 150 (COMPRESORES)
# 124              ISO PAG 220 (COMPRESORES)
# 125          DIELÉCTRICO (NORMA AMERICANA)
# 126            DIELÉCTRICO (NORMA EUROPEA)
# 127                        INDUSTRIAL EP 2
# 128                        INDUSTRIAL EP 2
# 129                           JT-6 HI TEMP
# 130                           JT-6 HI TEMP
# 131                           JT-6 HI TEMP
# 27        TURBO SUPREMO DIESEL 15W-40 CK-4/SN   55.00  TAMBORES 55 GAL
# 28            TURBO DIESEL 15W-40 CJ-4/SN, SM    3.00      1/4 GALONES
# 29                       NATURAL GAS W 15W-40   55.00  TAMBORES 55 GAL
# ..                                        ...     ...              ...
# 119               LUBCOMPRESO SINTÉTICO AT 68   55.00  TAMBORES 55 GAL
# 120                       LUBCOMPRESO ISO 100    5.00     CANECA 5 GAL
# 121                       LUBCOMPRESO ISO 100   55.00  TAMBORES 55 GAL
# 122                       LUBCOMPRESO ISO 150    5.00     CANECA 5 GAL
# 123                       LUBCOMPRESO ISO 150   55.00  TAMBORES 55 GAL
# 124                       LUBCOMPRESO ISO 220    5.00     CANECA 5 GAL
# 125               D´ELÉCTRICO NORMA AMERICANA   55.00  TAMBORES 55 GAL
# 126                 D´ELÉCTRICO NORMA EUROPEA   55.00  TAMBORES 55 GAL
# 127                     GRASA INDUSTRIAL EP 2    4.53    CANECA 16 KGS
# 128                     GRASA INDUSTRIAL EP 2   51.81   TAMBOR 180 KGS
# 129                                SEVERGRASA     NaN         14 ONZAS
# 130                                SEVERGRASA    4.53    CANECA 35 LBS
# 131                                SEVERGRASA   51.81   TAMBOR 400 LBS
# 132                       GRASA CHASIS CALCIO     NaN         14 ONZAS
# 133                       GRASA CHASIS CALCIO    4.53    CANECA 35 LBS
# 134                       GRASA CHASIS CALCIO   51.81   TAMBOR 400 LBS
# 135                               GRASA LITIO     NaN         14 ONZAS
# 136                               GRASA LITIO    4.53    CANECA 35 LBS
# 137                               GRASA LITIO   51.81   TAMBOR 400 LBS
# 138                           ACEITE AGRICOLA    1.00        AL GRANEL
# 139          BASE LUBRICANTE LIVIANA (SN 150)    1.00        AL GRANEL
# 140          BASE LUBRICANTE MEDIANA (SN 325)    1.00        AL GRANEL
# 141          BASE LUBRICANTE MEDIANA (SN 550)    1.00        AL GRANEL
# 142     BASE LUBRICANTE PESADA (BRIGHT STOCK)    1.00        AL GRANEL
# 143             PETRO COOLER  SERVICIO LIGERO    3.00      1/4 GALONES
# 144             PETRO COOLER  SERVICIO LIGERO    4.00          GALONES
# 145             PETRO COOLER  SERVICIO PESADO    3.00      1/4 GALONES
# 146             PETRO COOLER  SERVICIO PESADO    4.00          GALONES
# 147                   PETRO BRAKE FLUID DOT-3    3.00      1/4 GALONES
# 148                   PETRO BRAKE FLUID DOT-4    3.00      1/4 GALONES
#
#                                         sub
# 0       LUBRICANTES PARA MOTORES A GASOLINA
# 1       LUBRICANTES PARA MOTORES A GASOLINA
# 2       LUBRICANTES PARA MOTORES A GASOLINA
# 3       LUBRICANTES PARA MOTORES A GASOLINA
# 4       LUBRICANTES PARA MOTORES A GASOLINA
# 5       LUBRICANTES PARA MOTORES A GASOLINA
# 6       LUBRICANTES PARA MOTORES A GASOLINA
# 7     LUBRICANTES PARA MOTORES DE 4 TIEMPOS
# 8     LUBRICANTES PARA MOTORES DE 4 TIEMPOS
# 9     LUBRICANTES PARA MOTORES DE 4 TIEMPOS
# 10    LUBRICANTES PARA MOTORES DE 4 TIEMPOS
# 11    LUBRICANTES PARA MOTORES DE 4 TIEMPOS
# 12      LUBRICANTES PARA MOTORES A GASOLINA
# 13      LUBRICANTES PARA MOTORES A GASOLINA
# 14      LUBRICANTES PARA MOTORES A GASOLINA
# 15      LUBRICANTES PARA MOTORES A GASOLINA
# 16      LUBRICANTES PARA MOTORES A GASOLINA
# 17      LUBRICANTES PARA MOTORES A GASOLINA
# 18        LUBRICANTES PARA MOTORES A DIESEL
# 19        LUBRICANTES PARA MOTORES A DIESEL
# 20        LUBRICANTES PARA MOTORES A DIESEL
# 21        LUBRICANTES PARA MOTORES A DIESEL
# 22        LUBRICANTES PARA MOTORES A DIESEL
# 23        LUBRICANTES PARA MOTORES A DIESEL
# 24        LUBRICANTES PARA MOTORES A DIESEL
# 25        LUBRICANTES PARA MOTORES A DIESEL
# 26        LUBRICANTES PARA MOTORES A DIESEL
# 27        LUBRICANTES PARA MOTORES A DIESEL
# 28        LUBRICANTES PARA MOTORES A DIESEL
# 29   LUBRICANTES PARA MOTORES A GAS NATURAL
# ..                                      ...
# 119                LUBRICANTES INDUSTRIALES
# 120                LUBRICANTES INDUSTRIALES
# 121                LUBRICANTES INDUSTRIALES
# 122                LUBRICANTES INDUSTRIALES
# 123                LUBRICANTES INDUSTRIALES
# 124                LUBRICANTES INDUSTRIALES
# 125     ACEITE DIELÉCTRICO/ TRANSFORMADORES
# 126     ACEITE DIELÉCTRICO/ TRANSFORMADORES
# 127                                  GRASAS
# 128                                  GRASAS
# 129                                  GRASAS
# 130                                  GRASAS
# 131                                  GRASAS
# 132                                  GRASAS
# 133                                  GRASAS
# 134                                  GRASAS
# 135                                  GRASAS
# 136                                  GRASAS
# 137                                  GRASAS
# 138                    PRODUCTOS ESPECIALES
# 139                    PRODUCTOS ESPECIALES
# 140                    PRODUCTOS ESPECIALES
# 141                    PRODUCTOS ESPECIALES
# 142                    PRODUCTOS ESPECIALES
# 143                    PRODUCTOS ESPECIALES
# 144                    PRODUCTOS ESPECIALES
# 145                    PRODUCTOS ESPECIALES
# 146                    PRODUCTOS ESPECIALES
# 147                    PRODUCTOS ESPECIALES
# 148                    PRODUCTOS ESPECIALES
#
# [149 rows x 5 columns]

# %%
with pd.ExcelWriter('C:\\Users\\Carlos\\Documents\\GitHub\\py-Aguirre-Maldonado-Carlos-Arturo\\Examen_IIB\\examen-python\\documentos finales\\productos-py.xlsx', engine='openpyxl', mode='a') as writer:
    df2.to_excel(writer)

# %%
writer = pd.ExcelWriter('C:\\Users\\Carlos\\Documents\\GitHub\\py-Aguirre-Maldonado-Carlos-Arturo\\Examen_IIB\\examen-python\\documentos finales\\productos-py.xlsx',engine='openpyxl', mode='a')
writer
# Out:
#   File "<ipython-input-233-8281faabe860>", line 2
#     , engine='openpyxl', mode='a')
#     ^
# SyntaxError: invalid syntax

# %%
df.to_excel('C:\\Users\\Carlos\\Documents\\GitHub\\py-Aguirre-Maldonado-Carlos-Arturo\\Examen_IIB\\examen-python\\documentos finales\\productos-py.xlsx')
